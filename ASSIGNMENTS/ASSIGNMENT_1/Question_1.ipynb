# %%
# Importing all the required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
# setting seed value
seed=250
np.random.seed(250)

# %% [markdown]
# 1. Read the dataset in file1.csv into a pandas dataframe.

# %%
dataset=pd.read_csv('file1.csv',index_col=False)
# header = None is not used here because we need header titles to understand the description 
dataset
# Out:
#      attr1  attr2  attr3  attr4  attr5  attr6  attr7   atr8  attr9  attr10  \
# 0     42.9   26.0   31.5   13.1   10.4   18.8   14.1  106.2   71.5    32.5
# 1     43.7   28.5   33.5   14.0   11.8   20.6   15.1  110.5   79.0    34.4
# 2     40.1   28.2   33.3   13.9   10.9   19.7   14.1  115.1   83.2    33.4
# 3     44.3   29.9   34.0   13.9   11.2   20.9   15.0  104.5   77.8    31.0
# 4     41.0   26.8   32.2   14.9   10.6   17.8   14.0  107.5   78.0    36.0
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 441   38.5   25.6   31.7   11.8   10.2   16.8   12.9   92.8   74.7    28.1
# 442   35.3   25.4   28.5   10.6   10.4   17.0   12.6   95.9   60.8    26.8
# 443   36.2   28.7   27.8   12.4   10.2   17.9   13.2   96.1   66.9    26.2
# 444   34.9   28.7   32.9   13.4   10.8   17.9   12.9   98.5   68.8    29.6
# 445   38.7   29.7   32.0   12.8   10.5   18.4   13.8  103.8   63.7    26.4
#
#      attr11  attr12  attr13  attr14  attr15  attr16  attr17  attr18
# ...

# %% [markdown]
# 2. Display the corresponding data description file desc1.txt and understand the contents of the data in file1.csv

# %%
file_obj=open('desc1.txt.txt','r')
print(file_obj.read())
file_obj.close()
# Out:
# Body measurements of 446 physically active individuals.
#
# Description
# Body girth measurements and skeletal diameter measurements, as well as age, weight and gender, are given for 446 physically active individuals - 223 men and 223 women.
#
# Format
# A data frame with 446 observations on the following 18 variables.
#
# attr1
# A numerical vector, respondent's biacromial diameter in centimeters.
#
# attr2
# A numerical vector, respondent's biiliac diameter (pelvic breadth) in centimeters.
#
# attr3
# A numerical vector, respondent's bitrochanteric diameter in centimeters.
#
# attr4
# A numerical vector, respondent's elbow diameter in centimeters, measured as sum of two elbows.
#
# attr5
# A numerical vector, respondent's wrist diameter in centimeters, measured as sum of two wrists.
#
# attr6
# A numerical vector, respondent's knee diameter in centimeters, measured as sum of two knees.
#
# attr7
# ...

# %% [markdown]
# 3. Replace the column names of data frame with meaningful column names, designed by you using the description in desc1.txt.

# %%
'''
Columns naming done wrong
'''
columns=['biacromial','biiliac','bitrochanteric','elbow','wrist D','knee D','ankle D','shoulder','waist','bicep','forearm','knee G','calf','ankle G','wrist G','age','Gender','Weight']
dataset.columns=columns
dataset
# Out:
#      biacromial  biiliac  bitrochanteric  elbow  wrist D  knee D  ankle D  \
# 0          42.9     26.0            31.5   13.1     10.4    18.8     14.1
# 1          43.7     28.5            33.5   14.0     11.8    20.6     15.1
# 2          40.1     28.2            33.3   13.9     10.9    19.7     14.1
# 3          44.3     29.9            34.0   13.9     11.2    20.9     15.0
# 4          41.0     26.8            32.2   14.9     10.6    17.8     14.0
# ..          ...      ...             ...    ...      ...     ...      ...
# 441        38.5     25.6            31.7   11.8     10.2    16.8     12.9
# 442        35.3     25.4            28.5   10.6     10.4    17.0     12.6
# 443        36.2     28.7            27.8   12.4     10.2    17.9     13.2
# 444        34.9     28.7            32.9   13.4     10.8    17.9     12.9
# 445        38.7     29.7            32.0   12.8     10.5    18.4     13.8
#
#      shoulder  waist  bicep  forearm  knee G  calf  ankle G  wrist G  age  \
# ...

# %% [markdown]
# 4. Display the maximum, minimum, median, first quartile, third quartile information for each column in the dataframe. Use an appropriate pandas command.

# %%
dataset.describe().T # Transposed the matrix
# Out:
#                 count        mean        std   min     25%     50%      75%  \
# biacromial      446.0   38.823991   3.052158  32.6  36.200   38.70   41.175
# biiliac         446.0   27.771525   2.201475  18.7  26.500   27.85   29.200
# bitrochanteric  446.0   31.944843   2.002236  26.3  30.600   32.00   33.300
# elbow           446.0   13.352915   1.359206   9.9  12.400   13.20   14.400
# wrist D         446.0   10.534753   0.958781   8.1   9.800   10.50   11.200
# knee D          446.0   18.772646   1.352456  15.7  17.900   18.70   19.600
# ankle D         446.0   13.830493   1.256878   9.9  12.900   13.80   14.800
# shoulder        446.0  108.186323  10.501635  85.9  99.325  108.30  116.675
# waist           446.0   77.090135  11.237657  57.9  68.000   75.55   84.650
# bicep           446.0   31.041928   4.249316  22.4  27.400   30.85   34.400
# forearm         446.0   25.898206   2.836281  19.6  23.400   25.80   28.375
# ...

# %% [markdown]
# 5. Use an appropriate pandas command to check if any column in the dataframe contains any missing value or not. Drop those rows if there are missing values in the row

# %%
# pandas command to check for number of NULL values in each column
dataset.isnull().sum()
# Out:
# biacromial        0
# biiliac           0
# bitrochanteric    0
# elbow             0
# wrist D           0
# knee D            0
# ankle D           0
# shoulder          0
# waist             0
# bicep             0
# forearm           0
# knee G            0
# calf              0
# ankle G           0
# wrist G           0
# age               0
# Gender            0
# Weight            0
# dtype: int64

# %%
# Total number of null values in the entire dataset
dataset.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# - Since there are no NULL values in the dataset so I cannot remove any Rows. However I will be writing the code for removing rows wiyh NULL values.

# %%
'''
Demo code for dropping rows

dataset.dropna(inplace=True)

'''
# Out:
# '\nDemo code for dropping rows\n\ndataset.dropna(inplace=True)\n\n'

# %% [markdown]
# 1. Consider the weight attribute as the response variable and all other attributes as predictor variables
# 2. So Y=Weight  beta=Columns from 0 to 17

# %% [markdown]
# 6. Split the data into two sets such that 80% of the data is considered as set T1 and 20% of the data is considered as set T2.

# %%
T1_set=dataset.sample(frac=0.8,random_state=250)  # 250 is used to maintain seed value
T2_set=dataset.drop(T1_set.index)
print(len(T1_set),len(T2_set))
# Out:
# 357 89

# %% [markdown]
# 7.  Using T1 as training data, solve an ordinary least squares regression problem and obtain the regression coefficients. Using these coefficients, compute the R2 and mean squared error values on the training set T1 and test set T2

# %%
response_cols=['Weight']
predictor_columns=dataset.drop(columns=['Weight'])  # Extracting the predictor columns
#print(predictor_columns,len(predictor_columns))
T1_train=T1_set.drop(columns=response_cols,axis=1) 
T2_test=T2_set.drop(columns=response_cols,axis=1) 
T1_train
# Out:
#      biacromial  biiliac  bitrochanteric  elbow  wrist D  knee D  ankle D  \
# 445        38.7     29.7            32.0   12.8     10.5    18.4     13.8
# 176        41.9     27.8            33.3   15.1     11.3    19.2     14.9
# 76         40.8     27.1            29.4   13.3     10.4    18.5     12.8
# 35         38.3     25.2            30.2   13.2     10.4    18.8     13.0
# 249        39.1     27.5            34.0   12.6     10.0    18.0     12.7
# ..          ...      ...             ...    ...      ...     ...      ...
# 92         37.6     24.4            28.3   12.9     10.8    18.0     14.3
# 252        35.0     26.0            29.8   12.4      9.5    17.2     12.3
# 208        40.9     24.4            30.6   13.8     11.5    19.0     15.1
# 12         42.3     26.4            31.2   14.6     10.8    18.6     13.8
# 290        38.2     30.0            35.5   12.6     10.8    19.5     13.6
#
#      shoulder  waist  bicep  forearm  knee G  calf  ankle G  wrist G  age  \
# ...

# %%
T2_test
# Out:
#      biacromial  biiliac  bitrochanteric  elbow  wrist D  knee D  ankle D  \
# 2          40.1     28.2            33.3   13.9     10.9    19.7     14.1
# 3          44.3     29.9            34.0   13.9     11.2    20.9     15.0
# 4          41.0     26.8            32.2   14.9     10.6    17.8     14.0
# 9          43.6     29.3            34.4   15.4     10.9    20.7     15.5
# 14         44.8     27.8            32.2   15.2     11.6    19.4     14.7
# ..          ...      ...             ...    ...      ...     ...      ...
# 419        37.4     29.0            32.9   12.7     10.0    18.2     13.8
# 429        34.0     25.9            29.4   11.4      9.6    16.6     12.6
# 432        36.5     27.5            30.8   11.6      9.6    17.0     11.7
# 436        39.4     28.3            30.2   12.8     10.5    19.5     14.4
# 438        35.8     27.3            28.5   11.2     10.2    17.5     12.9
#
#      shoulder  waist  bicep  forearm  knee G  calf  ankle G  wrist G  age  \
# ...

# %%
# converting predictor variables to numpy array
T1_train=T1_train.to_numpy()
T2_test=T2_test.to_numpy()
print(T1_train.shape,T2_test.shape)
# Out:
# (357, 17) (89, 17)

# %%
# Add a column of 1's to account for the beta0 in the matrix multiplication Y=beta0 + beta1*x1+....
X_train=np.hstack((T1_train, np.ones((T1_train.shape[0], 1), dtype=T1_train.dtype)))
X_test=np.hstack((T2_test, np.ones((T2_test.shape[0], 1), dtype=T2_test.dtype)))
print(X_train.shape,X_test.shape)
# Out:
# (357, 18) (89, 18)

# %%
# Convert respective response variables into numpy arrays
Y_train=T1_set[response_cols].to_numpy()
Y_test=T2_set[response_cols].to_numpy()
print(Y_train.shape,Y_test.shape)
# Out:
# (357, 1) (89, 1)

# %%
#Finding beta values

XTX = np.matmul(np.transpose(X_train),X_train)
#print('XTX shape:',XTX.shape)
#condition number of XTX
print('Condition Number',np.linalg.cond(XTX))

Xy = np.matmul(np.transpose(X_train),Y_train)
#print('Xy shape:',Xy.shape)

beta = np.matmul(np.linalg.inv(XTX),Xy)

print('Beta values',beta.shape)
print(beta)
# Out:
# Condition Number 16553783.454535427
# Beta values (18, 1)
# [[ 1.81097112e-01]
#  [ 2.84194191e-01]
#  [ 3.73606557e-01]
#  [ 5.36518007e-01]
#  [ 1.81334800e-01]
#  [ 1.31302675e-01]
#  [ 7.78168875e-01]
#  [ 2.10537523e-01]
#  [ 5.06936397e-01]
#  [ 3.33486884e-01]
#  [ 2.22786726e-01]
#  [ 8.23751255e-01]
#  [ 3.46770907e-01]
#  [-1.31481737e-01]
#  [-3.34812764e-02]
#  [-1.11144511e-01]
#  [-2.47148759e+00]
#  [-9.23906686e+01]]

# %%
# R**2 value and MSE value of Train set

#Compute y_bar 
y_bar = np.mean(Y_train)
#print('y_bar of Train set',y_bar)

# Computing variance of y
sigma_yy = 0
for i in range(Y_train.shape[0]): #access each row from the data set 
  y_i = Y_train[i] 
  sigma_yy += (y_i-y_bar)**2

#print('sigma_yy of of Train set:', sigma_yy)

#Compute sum of squared residuals 
sum_sq_residuals = 0
for i in range(Y_train.shape[0]): #access each row from the data set 
  x_i = X_train[i,:] #access i-th row of X
  y_i = Y_train[i] #access i-th row of y

  y_pred_i = np.dot(x_i,beta) #Computing the prediction obtained using the regression coefficients 
  e_i = y_i - y_pred_i #Difference between the actual observation y_i and prediction y_pred_i

  sum_sq_residuals += (e_i)**2

print('Sum of squared residuals:', sum_sq_residuals)

#Then we will compute the R^2 quantity
R_sq = 1-sum_sq_residuals/sigma_yy
print('R**2 value for Train set:',R_sq)
# Mean Squared error
print("Mean Squared Error (MSE) of Train set =",sum_sq_residuals/X_train.shape[0])
# Out:
# Sum of squared residuals: [2937.07038033]
# R**2 value for Train set: [0.95580563]
# Mean Squared Error (MSE) of Train set = [8.2270879]

# %%
# R**2 value of Test set

#Compute y_bar 
y_bar = np.mean(Y_test)
#print('y_bar of Test set',y_bar)

# Computing variance of y
sigma_yy = 0
for i in range(Y_test.shape[0]): #access each row from the data set 
  y_i = Y_test[i] 
  sigma_yy += (y_i-y_bar)**2

#print('sigma_yy of Test set:', sigma_yy)

#Compute sum of squared residuals 
sum_sq_residuals = 0
for i in range(Y_test.shape[0]): #access each row from the data set 
  x_i = X_test[i,:] #access i-th row of X
  y_i = Y_test[i] #access i-th row of y

  y_pred_i = np.dot(x_i,beta) #Computing the prediction obtained using the regression coefficients 
  e_i = y_i - y_pred_i #Difference between the actual observation y_i and prediction y_pred_i

  sum_sq_residuals += (e_i)**2

print('Sum of squared residuals:', sum_sq_residuals)

#Then we will compute the R^2 quantity
R_sq = 1-sum_sq_residuals/sigma_yy
print('R**2 value for Train set:',R_sq)
# MSE
print("Mean Squared Error (MSE) of Train set =",sum_sq_residuals/X_test.shape[0])
# Out:
# Sum of squared residuals: [812.1628316]
# R**2 value for Train set: [0.94322683]
# Mean Squared Error (MSE) of Train set = [9.12542507]

# %% [markdown]
# ### Train Set
# - R^2 value = 0.95580563
# - MSE value = 8.2270879
#
# ### Test Set
# - R^2 value = 0.94322683
# - MSE value = 9.12542507

# %% [markdown]
# 8. Also plot the residual vs fitted response values for the training set T1 and test set T2. Based on the plots, indicate if there are outliers in the training or test sets

# %%
# Train values Residual Plot for the train values
e_i_residuals_list = [] 
for i in range(X_train.shape[0]): 
  x_i = X_train[i,:] #access i-th row of X
  y_i = Y_train[i] #access i-th row of y

  y_pred_i = np.dot(x_i,beta) #compute the prediction obtained using the regression coefficients 
  e_i = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i

  e_i_residuals_list.append(e_i) #append the value of e_i to the list 

#plot the residuals e_i against the actual observations y_i
plt.scatter(Y_train, e_i_residuals_list,color='r')
plt.title("Residual plot on Training set")
plt.xlabel("Weight")
plt.ylabel("Residuals")
plt.grid()
plt.show()

# %%
# Test values Residual Plot for the train values
e_i_residuals_list = [] 
for i in range(X_test.shape[0]): 
  x_i = X_test[i,:] #access i-th row of X
  y_i = Y_test[i] #access i-th row of y

  y_pred_i = np.dot(x_i,beta) #compute the prediction obtained using the regression coefficients 
  e_i = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i

  e_i_residuals_list.append(e_i) #append the value of e_i to the list 

#plot the residuals e_i against the actual observations y_i
plt.scatter(Y_test, e_i_residuals_list,color='b')
plt.title("Residual plot on Test set")
plt.xlabel("Weight")
plt.ylabel("Residuals")
plt.grid()
plt.show()

# %% [markdown]
# ### Conclusion Based on plots

# %% [markdown]
# - Based on the Residual plots of Training Set we can say that there are two outliers at approximately 120 and 110 weight values.
#
# - For Test Residual Plot we cannot distinctly define whether that particular point is an outlier or not since the scatter points are uniformly distributed through out the residual plot. Though on an approximate basis we can argue that the points (58,-9),(87,8) and a few other points can behave as outliers.
#
# - A detailed boxplot analysis is required to understand if the plots contain outliers or not.

# %% [markdown]
# 9. Based on R2 and mean squared error values and on the residual vs fit plots, discuss if the linear regression model assumption is good for the data, and if the model generalizes to unseen data. Also indicate if the residual behavior shows any pattern based on the fitted values.

# %%
# Plot for relationship between Actual and Predicted VAlues for Train Data

y_pred_i = [] 
for i in range(X_train.shape[0]): 
  x_i = X_train[i,:] #access i-th row of X
  y_i = Y_train[i] #access i-th row of y

  y_pred_i.append(np.dot(x_i,beta))

#plot the residuals e_i against the actual observations y_i
plt.scatter(Y_train, y_pred_i,color='r')
plt.title("True VS Predicted Values on Train Dataset (T1)")
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.grid()
plt.show()

# %%
# Plot for relationship between Actual and Predicted VAlues for Test Data

y_pred_i = [] 
for i in range(X_test.shape[0]): 
  x_i = X_test[i,:] #access i-th row of X
  y_i = Y_test[i] #access i-th row of y

  y_pred_i.append(np.dot(x_i,beta))

#plot the residuals e_i against the actual observations y_i
plt.scatter(Y_test, y_pred_i,color='b')
plt.title("True VS Predicted Values on Test Dataset (T2)")
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.grid()
plt.show()

# %% [markdown]
# - Based on the residual plots as presented above we see no distinct feature or pattern among the points. The points are uniformly distributed across the space.
#
# - The R2 values of the training nad test sets are 0.956 and 0.94 which is fairly good and within acceptable ranges.
#
# - From the above plots of True values and predicted values we can see a nearabout linear relationship defining those points accurately. So it is sufficient to say that the linear regression model is a good fit for the data.

# %% [markdown]
# 10. Now, to perform ℓ2 regularized ordinary least squares regression, choose regularization constant λ ∈ {10−5, 10−4, 10−3, 10−2, 10−1, 1, 10, 100, 1000, 10000} using a 5-fold crossvalidation on the full train set T1. Use average R2 scores of the folds as the criterion to choose best regularization parameter. Perform ℓ2 regularized ordinary least squares regression with best regularization parameter obtained from the  cross-validation procedure on the set T1 and obtain the regression coefficients. Using these coefficients, compute the R2 and mean squared
# error values on the training set T1 and test set T2.

# %%
# Function to compute R2 and MSE

def compute_Rsquared_and_MSE(beta, X, Y): 

  #first we shall compute y_bar 
  y_bar = Y.mean()
  #print('y_bar',y_bar)

  sigma_yy = 0
  for i in range(Y.shape[0]): 
       y_i = Y[i] 
       sigma_yy += (y_i-y_bar)**2
  #print('sigma_yy:', sigma_yy)

  #print('\n_________________________\n')

  #now we can compute sum of squared residuals 
  sum_sq_residuals = 0.
  for i in range(Y.shape[0]): #access each row from the data set 
    x_i = X[i,:] #access i-th row of X
    y_i = Y[i] #access i-th row of y

    y_pred_i = np.dot(x_i,beta) #compute the prediction obtained using the regression coefficients 
    e_i = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i

    sum_sq_residuals += (e_i)**2

    
  #Then we will compute the R^2 quantity and MSE
  R_sq = 1-sum_sq_residuals/sigma_yy
  MSE = sum_sq_residuals/Y.shape[0]
  #print('R^2 :',R_sq, ' MSE:',MSE)
  return R_sq, MSE

# %%
import scipy
from scipy import linalg

#print(T1_set.shape)

seeds = [100, 200,300,400,500] # Since 5 fold cross validation is chosen so 5 seeds are given

lambda_val = [pow(10,-5),pow(10,-4),pow(10,-3),pow(10,-2),pow(10,-1),1,10,100,1000,10000]

train_R2_seeds = [] 
val_R2_seeds = [] 

train_MSE_seeds = [] 
val_MSE_seeds = [] 
for seed in seeds: 
  T1_train = T1_set.sample(frac=0.8,random_state=seed) # since 5 five fold cross validation so dataset is divided into 5 chunks. So validation frac=0.2
  T1_val = T1_set.drop(T1_train.index)
  #print(T1_train.shape,T1_val.shape)
  #print(T1_train.Weight)
  X_val = T1_val.drop(columns=response_cols,axis=1)
  X_train = T1_train.drop(columns=response_cols,axis=1)
  

  X_train = X_train.to_numpy()
  X_val = X_val.to_numpy()

  X_train = np.hstack((X_train, np.ones((X_train.shape[0], 1), dtype=X_train.dtype)))
  X_val = np.hstack((X_val, np.ones((X_val.shape[0], 1), dtype=X_val.dtype)))
  
  Y_train = T1_train[response_cols].to_numpy()
  Y_val = T1_val[response_cols].to_numpy()

  train_R2_lambdas = []
  val_R2_lambdas = []

  train_MSE_lambdas = []
  val_MSE_lambdas = []
  
  for lambda_ in lambda_val:
    XTX = np.matmul(np.transpose(X_train),X_train)
    Xy = np.matmul(np.transpose(X_train),Y_train)
    I = np.identity(X_train.shape[1])

    beta =scipy.linalg.solve( XTX+lambda_*I,Xy)
    #print('lambda:',lambda_)
    #print('beta:',beta)
    #print('***************')

    train_R2, train_MSE = compute_Rsquared_and_MSE(beta, X_train, Y_train)
    train_R2_lambdas.append(train_R2)
    train_MSE_lambdas.append(train_MSE)

    val_R2, val_MSE = compute_Rsquared_and_MSE(beta, X_val, Y_val)
    val_R2_lambdas.append(val_R2)
    val_MSE_lambdas.append(val_MSE)

  train_R2_seeds.append(np.array(train_R2_lambdas))
  train_MSE_seeds.append(np.array(train_MSE_lambdas))

  val_R2_seeds.append(np.array(val_R2_lambdas))
  val_MSE_seeds.append(np.array(val_MSE_lambdas))

val_R2_seeds = np.array(val_R2_seeds).squeeze()
print(val_R2_seeds)

mean_val_R2_lambdas = np.mean(val_R2_seeds,axis=0)

train_R2_seeds = np.array(train_R2_seeds).squeeze()
print(train_R2_seeds)

mean_train_R2_lambdas = np.mean(train_R2_seeds,axis=0)

print('5-fold train R2 values:', train_R2_seeds,'\n')

print('5-fold train MSEs:', train_MSE_seeds,'\n')

print('5-fold val R2 values:', mean_val_R2_lambdas.squeeze(),'\n')
print('5-fold train R2 values:', mean_train_R2_lambdas.squeeze(),'\n')

#print('k-fold val MSEs:', val_MSE_seeds)


best_lambda_idx = np.argmax(mean_val_R2_lambdas)
best_lambda = lambda_val[best_lambda_idx]

print('best lambda:', best_lambda)
# Out:
# [[0.95494722 0.95494879 0.9549641  0.95508143 0.95377317 0.92042764
#   0.87850978 0.85806916 0.84441459 0.79700437]
#  [0.95321933 0.9532159  0.95318146 0.95281884 0.94804734 0.90943794
#   0.87043205 0.85212289 0.83916453 0.78533667]
#  [0.94328954 0.9432922  0.94331855 0.94355524 0.94399155 0.92464557
#   0.89741831 0.88201862 0.86620486 0.80680446]
#  [0.9471359  0.94713637 0.94714067 0.94714386 0.94444827 0.90081372
#   0.85195229 0.82885561 0.807643   0.76293301]
#  [0.95256822 0.95256971 0.95258429 0.95269486 0.95134972 0.91799611
#   0.88204642 0.87556602 0.86430947 0.80345748]]
# [[0.9548508  0.95485079 0.95485045 0.95481769 0.9524945  0.91897092
#   0.88261258 0.86915638 0.85423917 0.79760469]
#  [0.95488982 0.95488981 0.95488949 0.9548584  0.95264111 0.9199913
#   0.88334367 0.86801328 0.85222056 0.79437014]
#  [0.95805778 0.95805778 0.95805744 0.95802518 0.95569624 0.91992701
#   0.87834765 0.86182472 0.84637036 0.79069448]
# ...

# %%
# Obtaining beta fron the best lamda

X_train = T1_set.drop(columns=response_cols)
X_train = X_train.to_numpy()

X_train = np.hstack((X_train, np.ones((X_train.shape[0], 1), dtype=X_train.dtype)))
Y_train = T1_set[response_cols].to_numpy()

XTX = np.matmul(np.transpose(X_train),X_train)
Xy = np.matmul(np.transpose(X_train),Y_train)
I = np.identity(X_train.shape[1])

final_beta =scipy.linalg.solve( XTX+best_lambda*I,Xy)
print('lambda:',best_lambda)
print('Final beta:',final_beta.shape,'\n',final_beta)
#print('***************')
# Out:
# lambda: 0.01
# Final beta: (18, 1)
#  [[ 1.66673598e-01]
#  [ 2.77294652e-01]
#  [ 3.67516154e-01]
#  [ 5.52994571e-01]
#  [ 1.78626675e-01]
#  [ 1.26196476e-01]
#  [ 7.62232067e-01]
#  [ 2.06232019e-01]
#  [ 5.09818572e-01]
#  [ 3.42720762e-01]
#  [ 2.11292881e-01]
#  [ 8.23451040e-01]
#  [ 3.48753766e-01]
#  [-1.33417198e-01]
#  [-4.82312890e-02]
#  [-1.11730754e-01]
#  [-2.33755497e+00]
#  [-9.08923467e+01]]

# %%
X_train=T1_set.drop(columns=response_cols).to_numpy()
X_train = np.hstack((X_train, np.ones((X_train.shape[0], 1), dtype=X_train.dtype)))
Y_train=T1_set[response_cols].to_numpy()
X_test=T2_set.drop(columns=response_cols).to_numpy()
X_test = np.hstack((X_test, np.ones((X_test.shape[0], 1), dtype=X_train.dtype)))
Y_test=T2_set[response_cols].to_numpy()

train_R2, train_MSE = compute_Rsquared_and_MSE(final_beta, X_train, Y_train)
test_R2, test_MSE = compute_Rsquared_and_MSE(final_beta, X_test, Y_test)

print('Train R^2 :', train_R2, ' Train MSE:', train_MSE)
print('Test R^2 :', test_R2, ' Test MSE:', test_MSE)
# Out:
# Train R^2 : [0.95578509]  Train MSE: [8.23091163]
# Test R^2 : [0.94308012]  Test MSE: [9.14900662]

# %% [markdown]
# - Train R^2 : [0.95578509]  Train MSE: [8.23091163]
# - Test R^2 : [0.94308012]  Test MSE: [9.14900662]

# %% [markdown]
# 11. Also plot the residual vs fitted response values for the training set T1 and test set T2. Discuss your observations.

# %%
# Train values Residual Plot for the train values
e_i_residuals_list = [] 
for i in range(X_train.shape[0]): 
  x_i = X_train[i,:] #access i-th row of X
  y_i = Y_train[i] #access i-th row of y

  y_pred_i = np.dot(x_i,final_beta) #compute the prediction obtained using the regression coefficients 
  e_i = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i

  e_i_residuals_list.append(e_i) #append the value of e_i to the list 

#plot the residuals e_i against the actual observations y_i
plt.scatter(Y_train, e_i_residuals_list,color='r')
plt.title("Residual plot on Training set")
plt.xlabel("Weight")
plt.ylabel("Residuals")
plt.grid()
plt.show()

# %%
# Test values Residual Plot for the train values
e_i_residuals_list = [] 
for i in range(X_test.shape[0]): 
  x_i = X_test[i,:] #access i-th row of X
  y_i = Y_test[i] #access i-th row of y

  y_pred_i = np.dot(x_i,final_beta) #compute the prediction obtained using the regression coefficients 
  e_i = y_i - y_pred_i #compute the difference between the actual observation y_i and prediction y_pred_i

  e_i_residuals_list.append(e_i) #append the value of e_i to the list 

#plot the residuals e_i against the actual observations y_i
plt.scatter(Y_test, e_i_residuals_list,color='b')
plt.title("Residual plot on Test set")
plt.xlabel("Weight")
plt.ylabel("Residuals")
plt.grid()
plt.show()

# %% [markdown]
# ### Observations
# - Not much change in residual plot of Train data.
# - The points on the test data appear to be spread out much more in this case.
# - Outliers are much clearer in this cases.

# %% [markdown]
# 12. Compare the R2 , mean squared error values and residual plots for unregularized and regularized linear regression. Discuss your observations.
